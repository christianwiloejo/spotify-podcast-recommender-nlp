# %%
import json, re, nltk

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import pandas as pd

import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.stem.wordnet import WordNetLemmatizer

stopwords = set(nltk.corpus.stopwords.words('english'))

# %%
raw_dat = pd.read_csv('../script_output/episode_transcript_data_w_metadata.csv')
raw_dat.head()
# Out:
#    index                             show_uri  \
# 0      0  spotify:show:2NYtxEZyYelR6RMKmjfPLB
# 1      1  spotify:show:15iWCbU7QoO23EndPEO6aN
# 2      2  spotify:show:6vZRgUFTYwbAA79UNCADr4
# 3      3  spotify:show:5BvKEjaMSuvUsGROGi2S7s
# 4      4  spotify:show:7w3h3umpH74veEJcbE6xf4
#
#                                            show_name  \
# 0                               Kream in your Koffee
# 1                              Morning Cup Of Murder
# 2  Inside The 18 : A Podcast for Goalkeepers by G...
# 3                                    Arrowhead Live!
# 4                                              FBoL
#
#                                     show_description               publisher  \
# 0  A 20-something blunt female takes on the world...             Katie Houle
# 1  Ever wonder what murder took place on today in...   Morning Cup Of Murder
# 2  Inside the 18 is your source for all things Go...  Inside the 18 GK Media
# 3  Your favorite podcast for everything @Chiefs! ...         Arrowhead Live!
# 4  The comedy podcast about toxic characters, wri...           Emily Edwards
#
#     language                                           rss_link  \
# 0     ['en']           https://anchor.fm/s/11b84b68/podcast/rss
# 1     ['en']            https://anchor.fm/s/b07181c/podcast/rss
# 2     ['en']            https://anchor.fm/s/81a072c/podcast/rss
# 3  ['en-US']            https://anchor.fm/s/917dba4/podcast/rss
# 4     ['en']  https://www.fuckboisoflit.com/episodes?format=rss
#
#                               episode_uri  \
# 0  spotify:episode:000A9sRBYdVh66csG2qEdj
# 1  spotify:episode:000HP8n3hNIfglT2wSI2cA
# 2  spotify:episode:001UfOruzkA3Bn1SPjcdfa
# 3  spotify:episode:001i89SvIQgDuuyC53hfBm
# 4  spotify:episode:0025RWNwe2lnp6HcnfzwzG
#
#                                         episode_name  \
# 0                            1: It’s Christmas Time!
# 1  The Goleta Postal Facility shootings- January ...
# 2  Ep.36 - Incorporating a Singular Goalkeeping C...
# 3                   Episode 1: Arrowhead Live! Debut
# 4  The Lion, The Witch, And The Wardrobe - Ashley...
#
#                                  episode_description   duration  \
# 0  On the first ever episode of Kream in your Kof...  12.700133
# 1  See something, say something. It’s a mantra ma...   6.019383
# 2  Today’s episode is a sit down Michael and Omar...  43.616333
# 3  Join us as we take a look at all current Chief...  58.189200
# 4  The modern morality tail of how to stay good f...  51.782050
#
#           show_filename_prefix episode_filename_prefix  Unnamed: 0  \
# 0  show_2NYtxEZyYelR6RMKmjfPLB  000A9sRBYdVh66csG2qEdj       34866
# 1  show_15iWCbU7QoO23EndPEO6aN  000HP8n3hNIfglT2wSI2cA       14162
# 2  show_6vZRgUFTYwbAA79UNCADr4  001UfOruzkA3Bn1SPjcdfa       93168
# 3  show_5BvKEjaMSuvUsGROGi2S7s  001i89SvIQgDuuyC53hfBm       69703
# 4  show_7w3h3umpH74veEJcbE6xf4  0025RWNwe2lnp6HcnfzwzG      104381
#
#                   episode                                         transcript
# 0  000A9sRBYdVh66csG2qEdj  Hello. Hello. Hello everyone. This is Katie an...
# 1  000HP8n3hNIfglT2wSI2cA  There were two more murders 15 miles away arri...
# 2  001UfOruzkA3Bn1SPjcdfa  Welcome to inside the 18. Today's episode is t...
# 3  001i89SvIQgDuuyC53hfBm  Hey cheese fans before we get started. I wante...
# 4  0025RWNwe2lnp6HcnfzwzG  Sorry to interrupt the show, but I do have to ...

# %%
raw_dat = raw_dat.dropna()

# %%
def tokenize_titles(title):
    tokens = nltk.word_tokenize(title)
    lmtzr = WordNetLemmatizer()
    filtered_tokens = []
    
    for token in tokens:
        token = token.replace("'s", " ").replace("n’t", " not").replace("’ve", " have")
        token = re.sub(r'[^a-zA-Z0-9 ]', '', token)
        if token not in stopwords:
            filtered_tokens.append(token.lower())
    
    lemmas = [lmtzr.lemmatize(t,'v') for t in filtered_tokens]

    return lemmas

# %%
raw_dat['show_description_tokens'] = raw_dat.show_description.apply(tokenize_titles)
raw_dat['show_description_cleaned'] = raw_dat.show_description_tokens.str.join(' ')

# %%
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                stop_words = 'english',
                                lowercase = True,
                                #tokenizer=tokenize_titles,
                                max_features=500,
                                token_pattern = r'\b[a-zA-Z]{3,}\b',
                                max_df = 0.8, 
                                min_df = 20,
                                ngram_range=(2,4))
dtm_tf = tf_vectorizer.fit_transform(raw_dat.show_description_cleaned)
print(dtm_tf.shape)
# Out:
# (105153, 500)

# %%
lda_tf = LatentDirichletAllocation(n_components=5, 
                                   max_iter=100,
                                   learning_method='online', 
                                   random_state = 0, 
                                   n_jobs=-2)
lda_tf.fit(dtm_tf)
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=5, n_jobs=-2,
#                           random_state=0)

# %%
n_top_words = 30
tf_feature_names = tf_vectorizer.get_feature_names()

topics = dict()
for topic_idx, topic in enumerate(lda_tf.components_):
    topics[topic_idx] = [tf_feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
    print("Topic #%d:" % topic_idx)
    print(" | ".join([tf_feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print("\n")
# Out:
# Topic #0:
# new episodes | true crime | mental health | social media | parcast network | cutler media | talk things | audio experience | youtube channel | gary vaynerchuk | make sure | podcast talk | latest news | share stories | serial killers | help people | real life | media production | current events | new podcast | network cutler media production | network cutler media | parcast network cutler | parcast network cutler media | network cutler | cutler media production | podcast discuss | follow instagram | new york | episodes release
#
#
# Topic #1:
# support podcast | support podcast https | podcast https | personal development | audioblog blogcast | daily audioblog | think optimal | daily audioblog blogcast | podcast support | podcast feature | podcast support podcast | podcast support podcast https | best blog | health fitness | single day | tip trick | blogcast support podcast | blogcast support podcast https | audioblog blogcast support | audioblog blogcast support podcast | daily audioblog blogcast support | blogcast support | best friends | podcast share | share experience | minutes day | sure subscribe | read best | special guests | official podcast
#
#
# Topic #2:
# podcast host | pop culture | weight loss | facebook instagram | intermittent fast | relate topics | million view | best sell | health relate | best sell book | sell book | ketogenic diet | youtube facebook | healthy weight | youtube facebook instagram | author best | author best sell | author best sell book | area expertise | body health | healthy lose | million followers | healthy lose healthy weight | youtube facebook instagram channel | healthy weight area | healthy weight area expertise | instagram channel | instagram channel close | healthy lose healthy | health director berg nutritionals
#
#
# Topic #3:
# weekly podcast | fun facts | stories fun | kid kid | parent time | kid hear | time easy | night tooth brush kid | parent time brush | morning night | morning night tooth | morning night tooth brush | riddle stories fun facts | riddle stories fun | time brush way recommend | time brush way | giggle brush minutes dentists | giggle brush minutes | giggle brush | fun facts silly songs | fun facts silly | minutes dentists recommend chompers | time brush | riddle stories | night tooth | night tooth brush | hear joke | hear joke riddle | hear joke riddle stories | kid kid hear
#
#
# Topic #4:
# support podcast | podcast https | support podcast https | podcast dedicate | cover art | help revise | core components | complicate revision | exams series | help rock | core components help | complicate revision subject | revision subject | components help rock | components help | core components help rock | components help rock exams | help rock exams | rock exams | podcast help | students break | exams series students | exams series students break | students help revise | students break complicate | students help | subject core components help | subject core | subject core components | revision subject core components

# %%
pyLDAvis.sklearn.prepare(lda_tf, dtm_tf, tf_vectorizer)
# Out:
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/christianwiloejo/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.217826 -0.300277       1        1  28.404496
# 2      0.203548  0.378440       2        1  24.894431
# 4     -0.302509 -0.004576       3        1  23.663465
# 1     -0.304784 -0.001375       4        1  12.252384
# 0      0.185919 -0.072212       5        1  10.785223, topic_info=                      Term          Freq         Total Category  logprob  \
# 432        support podcast  21743.000000  21743.000000  Default  30.0000
# 334          podcast https  21504.000000  21504.000000  Default  29.0000
# 433  support podcast https  21343.000000  21343.000000  Default  28.0000
# 287           new episodes   2762.000000   2762.000000  Default  27.0000
# 464             true crime   2192.000000   2192.000000  Default  26.0000
# ..                     ...           ...           ...      ...      ...
# 161       follow instagram    744.738867    745.549239   Topic5  -4.2427
# 290               new york    734.458727    735.269399   Topic5  -4.2566
# 134       episodes release    704.588083    705.395548   Topic5  -4.2981
# 80            change world    703.178941    703.987263   Topic5  -4.3001
# 496        youtube channel    958.376523   1727.287705   Topic5  -3.9905
#
#      loglift
# 432  30.0000
# 334  29.0000
# 433  28.0000
# 287  27.0000
# 464  26.0000
# ..       ...
# 161   2.2259
# 290   2.2259
# 134   2.2258
# 80    2.2258
# 496   1.6379
#
# [189 rows x 6 columns], token_table=      Topic      Freq                        Term
# term
# 0         2  0.998394                   age truth
# 1         2  0.998394           age truth healthy
# 2         2  0.998394      age truth healthy lose
# 7         2  0.998394               amazoncom new
# 8         2  0.998394          amazoncom new body
# ...     ...       ...                         ...
# 490       2  0.999076                 weight loss
# 496       3  0.444628             youtube channel
# 496       5  0.554627             youtube channel
# 497       2  0.999570            youtube facebook
# 498       2  0.999576  youtube facebook instagram
#
# [162 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 5, 2, 1])
